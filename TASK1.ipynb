# %% [markdown]
# <a href="https://colab.research.google.com/github/PriyankaManojaRout08/LETS_GROW_MORE_SEPTEMBER_2024/blob/main/TASK1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #NAME:- PRIYANKA MANOJA ROUT
#
# DATA SCIENCE SEPTEMBER INTERNSHIP PROGRAM
#
# INTERN AT LET'S GROW MORE
#
# LEVEL-BEGINNER
#
# TASK 1-IRIS FLOWER CLASSIFICATION ML PROJECT

# %% [markdown]
# # Importing libraries

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #Getting Dataset names from Seaborn Library

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %% [markdown]
# # Loading Dataset Iris

# %%
df=sns.load_dataset('iris')

# %%
print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.nunique()
# Out:
# sepal_length    35
# sepal_width     23
# petal_length    43
# petal_width     22
# species          3
# dtype: int64

# %%
df.shape
# Out:
# (150, 5)

# %%
df['sepal_length'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64>

# %% [markdown]
# # Subplots which includes Sactterplot,Swarmplot,Lineplot and Barplot

# %%
plt.figure(figsize=(8,6))

plt.subplot(2,2,1)
sns.scatterplot(x='sepal_length',y='species',color='green',data=df)

plt.subplot(2,2,2)
sns.swarmplot(x='sepal_length',y='species',color='yellow',data=df)

plt.subplot(2,2,3)
sns.lineplot(x='sepal_length',y='species',color='purple',data=df)

plt.subplot(2,2,4)
sns.barplot(x='sepal_length',y='species',color='pink',data=df)
# Out:
# <Axes: xlabel='sepal_length', ylabel='species'>

# %% [markdown]
# # Pair Plot

# %%
sns.pairplot(df,hue='species')
plt.show()

# %%
sns.pairplot(df,hue='sepal_length')
plt.show()

# %% [markdown]
# # Heatmap

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-18-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %% [markdown]
# # Violin Plot

# %%
sns.violinplot(x ="sepal_width",y ="species",data =df)
# Out:
# <Axes: xlabel='sepal_width', ylabel='species'>

# %% [markdown]
# # Joint Plot

# %%
sns.jointplot(x = "sepal_length", y = "species", data = df)

# %% [markdown]
# # Stripplot

# %%
sns.stripplot(x = "sepal_length", y = "species", data = df)
# Out:
# <Axes: xlabel='sepal_length', ylabel='species'>
